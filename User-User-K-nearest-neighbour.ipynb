# %%
import warnings

# Suppress all warnings
warnings.filterwarnings("ignore")

from sklearn.preprocessing import LabelEncoder

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

# %%
# Load the CSV file into a DataFrame
df = pd.read_csv('pre_processed_data.csv')

# Drop rows where 'admit' column is 0
df = df[df['admit'] != 0]

# Reset index after dropping rows
df.reset_index(drop=True, inplace=True)

# %%
# Features (X)
X_user = df[['researchExp', 'industryExp', 'internExp', 'journalPubs', 'confPubs', 'cgpa', 'gre_score', 'univName']]

# Target (y)
y_user = df['userName']

# %%
# Initialize LabelEncoder
label_encoder = LabelEncoder()

# Fit and transform the 'univName' column
X_user['univName'] = label_encoder.fit_transform(X_user['univName'])

# Print the transformed DataFrame
print(X_user)
# Out:
#        researchExp  industryExp  internExp  journalPubs  confPubs    cgpa  \
# 0                0           18        5.0            0         0  0.8500
# 1                0           66        0.0            0         0  0.7828
# 2                0            0        0.0            0         0  0.5700
# 3                0            0        0.0            0         0  0.6220
# 4                0            0        0.0            0         0  0.5200
# ...            ...          ...        ...          ...       ...     ...
# 25827            0            0        0.0            0         0  0.7400
# 25828            0            0        0.0            0         0  0.8200
# 25829            0            0        0.0            0         0  0.8400
# 25830            0            0        0.0            0         0  0.7200
# 25831            0            0        0.0            0         0  0.9160
#
#        gre_score  univName
# 0            276        53
# 1            276        53
# 2            276        53
# 3            276        53
# 4            276        53
# ...          ...       ...
# 25827        300         0
# 25828        300         0
# 25829        300         0
# 25830        300         0
# 25831        300         0
#
# [25832 rows x 8 columns]

# %%
from scipy.stats import pearsonr


# Compute the correlation matrix
correlation_matrix = X_user.corr()

# Replace NaN values with 0 (if any)
correlation_matrix = correlation_matrix.fillna(0)

# Print the correlation matrix
print("Correlation Matrix:")
print(correlation_matrix)
# Out:
# Correlation Matrix:
#              researchExp  industryExp  internExp  journalPubs  confPubs  \
# researchExp     1.000000     0.154760   0.185785     0.227899  0.393235
# industryExp     0.154760     1.000000   0.230582     0.114637  0.129604
# internExp       0.185785     0.230582   1.000000     0.175792  0.144875
# journalPubs     0.227899     0.114637   0.175792     1.000000  0.298214
# confPubs        0.393235     0.129604   0.144875     0.298214  1.000000
# cgpa            0.011375    -0.007821   0.006393     0.004468  0.019463
# gre_score       0.024903    -0.043140   0.016955     0.018804  0.034626
# univName       -0.004072     0.003344   0.003629    -0.002442 -0.005425
#
#                  cgpa  gre_score  univName
# researchExp  0.011375   0.024903 -0.004072
# industryExp -0.007821  -0.043140  0.003344
# internExp    0.006393   0.016955  0.003629
# journalPubs  0.004468   0.018804 -0.002442
# confPubs     0.019463   0.034626 -0.005425
# cgpa         1.000000   0.069650  0.005120
# gre_score    0.069650   1.000000 -0.164956
# univName     0.005120  -0.164956  1.000000

# %%
###KNN
from sklearn.neighbors import KNeighborsRegressor
from sklearn.model_selection import train_test_split
import joblib

# Fill NaN and infinity values with 0
X_user.fillna(0, inplace=True)
X_user.replace([np.inf, -np.inf], 0, inplace=True)
y_user.fillna(0, inplace=True)
y_user.replace([np.inf, -np.inf], 0, inplace=True)

# Split the data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X_user, y_user, test_size=0.2, random_state=42)

y_train.to_csv('./djangoApp/gradvisor/y_train.csv', index=False)

# Define KNN model
knn = KNeighborsRegressor(n_neighbors=3)

# Fit KNN model on training data
knn.fit(X_train, y_train)

# Save the trained model
joblib.dump(knn, './djangoApp/gradvisor/knn_model.pkl')

# Compute similarity between test user and each user in the training data
top_similar_users = []
for i in range(len(X_test)):
    distances, indices = knn.kneighbors([X_test.iloc[i]], n_neighbors=3)
    top_similar_users.append([(idx, y_train.iloc[idx], 1 - distance) for distance, idx in zip(distances[0], indices[0])])

# Print the top 3 similar users for each test user
for test_user, similar_users in zip(y_test, top_similar_users):
    print(f"Test User: {test_user}, Top 3 Similar Users:")
    for idx, (user_idx, similarity, distance) in enumerate(similar_users):
        print(f"   {idx+1}. User Index: {user_idx}, Similarity: {similarity}, Distance: {distance}")
# Out:
# Test User: sai163, Top 3 Similar Users:
#    1. User Index: 14756, Similarity: Bontrey, Distance: 0.9955
#    2. User Index: 15548, Similarity: vickybogs, Distance: 0.992
#    3. User Index: 8742, Similarity: tachyon11, Distance: 0.991
# Test User: anand91, Top 3 Similar Users:
#    1. User Index: 11654, Similarity: enthusiastic, Distance: 0.9996999999999999
#    2. User Index: 2096, Similarity: vijay4454, Distance: 0.9996999999999999
#    3. User Index: 9713, Similarity: nehapawar, Distance: 0.9996999999999999
# Test User: Taruna_1, Top 3 Similar Users:
#    1. User Index: 2589, Similarity: siddhudb, Distance: 0.998
#    2. User Index: 10335, Similarity: kiranchitturi, Distance: 0.997
#    3. User Index: 6999, Similarity: ajay cj, Distance: 0.997
# Test User: raswashere, Top 3 Similar Users:
#    1. User Index: 12224, Similarity: niran3090, Distance: -0.4144907210724289
#    2. User Index: 48, Similarity: eeevk, Distance: -0.41477913470619154
#    3. User Index: 16044, Similarity: ashwinipatil9a, Distance: -0.41981548096927024
# Test User: vsakode, Top 3 Similar Users:
#    1. User Index: 2982, Similarity: msmohit004, Distance: 1.0
#    2. User Index: 2610, Similarity: rajanpawar, Distance: 1.0
#    3. User Index: 1517, Similarity: neileshc, Distance: 1.0
# Test User: supermanks, Top 3 Similar Users:
#    1. User Index: 2621, Similarity: shriramvenkat, Distance: 1.0
#    2. User Index: 599, Similarity: ambroprasanna, Distance: 0.999
#    3. User Index: 3595, Similarity: ryuzaki007, Distance: 0.998
# Test User: akhilgore, Top 3 Similar Users:
#    1. User Index: 0, Similarity: yashada7, Distance: 0.9998
#    2. User Index: 14560, Similarity: pmaheshwari, Distance: 0.9996
#    3. User Index: 9303, Similarity: harshalkasat, Distance: 0.9989
# Test User: Volts 440, Top 3 Similar Users:
#    1. User Index: 1406, Similarity: madhusudhan2310, Distance: 1.0
#    2. User Index: 1171, Similarity: shango, Distance: 1.0
#    3. User Index: 1069, Similarity: hh25, Distance: 1.0
# Test User: vicky512, Top 3 Similar Users:
#    1. User Index: 5280, Similarity: utsavkatira, Distance: 1.0
#    2. User Index: 260, Similarity: tanmayvg, Distance: 1.0
#    3. User Index: 3959, Similarity: ankit_2287, Distance: 1.0
# Test User: ashwintk, Top 3 Similar Users:
#    1. User Index: 8574, Similarity: johncena3, Distance: 1.0
#    2. User Index: 12223, Similarity: aswiniv, Distance: 0.9999999999999999
#    3. User Index: 395, Similarity: adithyaadhi, Distance: 0.9999999999999999
# Test User: bharathinaidu, Top 3 Similar Users:
#    1. User Index: 12981, Similarity: karthikeyanmani, Distance: 1.0
#    2. User Index: 4916, Similarity: sameer0016, Distance: 1.0
#    3. User Index: 12522, Similarity: erprateek, Distance: 1.0
# Test User: vrsndgr8, Top 3 Similar Users:
#    1. User Index: 951, Similarity: abhijit945, Distance: 1.0
#    2. User Index: 1757, Similarity: santhosh.nagaraj, Distance: 1.0
#    3. User Index: 1810, Similarity: Thieflord, Distance: 1.0
# Test User: aksr71, Top 3 Similar Users:
#    1. User Index: 1025, Similarity: aloksh589, Distance: 1.0
#    2. User Index: 14414, Similarity: german_shepherd, Distance: 1.0
#    3. User Index: 12364, Similarity: searcharun, Distance: 0.997
# Test User: praveen_rao, Top 3 Similar Users:
#    1. User Index: 11288, Similarity: prasannashreya, Distance: -0.00016019216923446322
#    2. User Index: 3469, Similarity: wingzero, Distance: -1.0003821659872894
#    3. User Index: 3082, Similarity: chandrashekar2277, Distance: -1.449536284687369
# Test User: nit90nat, Top 3 Similar Users:
#    1. User Index: 12609, Similarity: vidram, Distance: 1.0
#    2. User Index: 4437, Similarity: ankit_shah114, Distance: 1.0
#    3. User Index: 5659, Similarity: Sirisha224, Distance: 1.0
# Test User: mohanram, Top 3 Similar Users:
#    1. User Index: 9021, Similarity: manipalreddy, Distance: 1.0
#    2. User Index: 7253, Similarity: saurabh_861, Distance: 1.0
#    3. User Index: 5006, Similarity: grecracker, Distance: 1.0
# Test User: Kidrah22, Top 3 Similar Users:
#    1. User Index: 9979, Similarity: sanolution, Distance: 1.0
#    2. User Index: 552, Similarity: swapneelchitale1990, Distance: 1.0
#    3. User Index: 9799, Similarity: kaki_santu, Distance: 1.0
# Test User: sudarsanvsr2005, Top 3 Similar Users:
#    1. User Index: 747, Similarity: meenububbly2611, Distance: 1.0
#    2. User Index: 43, Similarity: abhishek1489, Distance: 1.0
#    3. User Index: 1199, Similarity: itgulpp, Distance: 1.0
# Test User: mihi, Top 3 Similar Users:
#    1. User Index: 19072, Similarity: architnandi, Distance: 1.0
#    2. User Index: 4168, Similarity: sshravan, Distance: 1.0
#    3. User Index: 2925, Similarity: aamir.irshad, Distance: 1.0
# Test User: adityar92, Top 3 Similar Users:
#    1. User Index: 18710, Similarity: prathmeshj25, Distance: 0.999
#    2. User Index: 7117, Similarity: siddhantkadam04, Distance: 0.9987
#    3. User Index: 15606, Similarity: roy5388, Distance: 0.9973000000000001
# Test User: rjmhmd, Top 3 Similar Users:
#    1. User Index: 19792, Similarity: kleptomaniac, Distance: 0.93
#    2. User Index: 9042, Similarity: pj0085545, Distance: -0.41471864340581877
#    3. User Index: 19028, Similarity: nishanth5028, Distance: -1.0030227157973024
# Test User: jubilant, Top 3 Similar Users:
#    1. User Index: 10536, Similarity: Apoorva_12, Distance: 1.0
#    2. User Index: 5290, Similarity: nandanh, Distance: 1.0
#    3. User Index: 864, Similarity: rgrer, Distance: 1.0
# Test User: anveshjarabani, Top 3 Similar Users:
#    1. User Index: 2922, Similarity: sudarshan_ramsub, Distance: 1.0
#    2. User Index: 342, Similarity: weltanschaunng, Distance: 1.0
#    3. User Index: 1839, Similarity: spraveen, Distance: 1.0
# Test User: soumyadutta, Top 3 Similar Users:
#    1. User Index: 7384, Similarity: srikanthgss, Distance: 1.0
#    2. User Index: 17169, Similarity: krishna.apple, Distance: 0.9999999999999999
#    3. User Index: 1482, Similarity: vishwanathan.shankar, Distance: 0.9999999999999999
# Test User: vssankar, Top 3 Similar Users:
#    1. User Index: 5946, Similarity: nandu28101989, Distance: 1.0
#    2. User Index: 5157, Similarity: gargisharma50, Distance: 1.0
#    3. User Index: 2649, Similarity: deepakmd, Distance: 1.0
# Test User: Dev04, Top 3 Similar Users:
#    1. User Index: 2537, Similarity: Adnilim Ved, Distance: 0.9996
#    2. User Index: 14932, Similarity: sam8dec, Distance: 0.9962
#    3. User Index: 14705, Similarity: srsnerdshack, Distance: 0.9959
# Test User: arunnd2000, Top 3 Similar Users:
#    1. User Index: 6671, Similarity: Kumaran90, Distance: -1.6017109754928582
#    2. User Index: 1268, Similarity: Kumaran90, Distance: -2.4305830408255678
#    3. User Index: 2012, Similarity: vishalsumani, Distance: -4.477225575051661
# Test User: venkateshreddy74, Top 3 Similar Users:
#    1. User Index: 6030, Similarity: gbharathwaj, Distance: 1.0
#    2. User Index: 2351, Similarity: chetancheetah, Distance: 1.0
#    3. User Index: 4214, Similarity: krishprasads, Distance: 1.0
# Test User: prodigy, Top 3 Similar Users:
#    1. User Index: 11623, Similarity: nehashj, Distance: 1.0
#    2. User Index: 2741, Similarity: maverick1990, Distance: 1.0
#    3. User Index: 9592, Similarity: chaituvitedu, Distance: 0.999
# Test User: abhijeet_gaikwad, Top 3 Similar Users:
#    1. User Index: 18942, Similarity: yoyoyaya, Distance: 0.9993000000000001
#    2. User Index: 19718, Similarity: kalyan89, Distance: 0.9986999999999999
#    3. User Index: 7327, Similarity: -KaaL-, Distance: 0.9930000000000001
# Test User: yash.ksagar, Top 3 Similar Users:
#    1. User Index: 13027, Similarity: prithachanana, Distance: 1.0
#    2. User Index: 8205, Similarity: aneeshpkulkarni, Distance: 1.0
#    3. User Index: 11909, Similarity: shivchetan, Distance: 1.0
# Test User: dnaveen, Top 3 Similar Users:
#    1. User Index: 7969, Similarity: moniblue, Distance: 1.0
#    2. User Index: 3080, Similarity: kristallizer, Distance: 0.99
#    3. User Index: 7317, Similarity: shan2389, Distance: 0.99
# Test User: Jaswanth Chowdary, Top 3 Similar Users:
#    1. User Index: 5526, Similarity: kousy007, Distance: 0.0
#    2. User Index: 3748, Similarity: banix, Distance: 0.0
#    3. User Index: 2005, Similarity: kunal.watkar, Distance: 0.0
# Test User: amok, Top 3 Similar Users:
#    1. User Index: 3554, Similarity: abha.1012, Distance: 1.0
#    2. User Index: 2344, Similarity: swaroopktr, Distance: 1.0
#    3. User Index: 3118, Similarity: AmitabhSural, Distance: 1.0
# Test User: sagnikrc, Top 3 Similar Users:
#    1. User Index: 17050, Similarity: notherbrick, Distance: 0.9986999999999999
#    2. User Index: 9141, Similarity: neerajpurandare, Distance: 0.9986999999999999
#    3. User Index: 12172, Similarity: HardeepJaswal, Distance: 0.9986999999999999
# Test User: rohit14, Top 3 Similar Users:
#    1. User Index: 8041, Similarity: vinutha k c, Distance: 1.0
#    2. User Index: 5907, Similarity: abhinavraj87, Distance: 1.0
#    3. User Index: 4850, Similarity: usdream11, Distance: 1.0
# Test User: sandeepoaks, Top 3 Similar Users:
#    1. User Index: 17553, Similarity: tookgre, Distance: 1.0
#    2. User Index: 4842, Similarity: abhi_br2589, Distance: 0.999
#    3. User Index: 37, Similarity: syed1, Distance: 0.999
# Test User: ogireddys, Top 3 Similar Users:
#    1. User Index: 8823, Similarity: pdaftari, Distance: -3.45
#    2. User Index: 17293, Similarity: sudharsan86, Distance: -6.489325737341113
#    3. User Index: 16555, Similarity: tuhin, Distance: -10.0025
# Test User: maddy1907, Top 3 Similar Users:
#    1. User Index: 16335, Similarity: pj0085545, Distance: -7.441723103784881e-05
#    2. User Index: 11970, Similarity: vlsims, Distance: -0.00026446502912413905
#    3. User Index: 13213, Similarity: poreddy.vishnuvardhan, Distance: -0.00026446502912413905
# Test User: ankita11, Top 3 Similar Users:
#    1. User Index: 9567, Similarity: whitetiger, Distance: 0.9970000000000001
#    2. User Index: 11473, Similarity: prasanthnarayan, Distance: 0.9970000000000001
#    3. User Index: 4320, Similarity: Shirrin, Distance: 0.997
# Test User: Notorious_Devil, Top 3 Similar Users:
#    1. User Index: 9548, Similarity: bhangepatil.akhilesh, Distance: 1.0
#    2. User Index: 8396, Similarity: karansheth, Distance: 1.0
#    3. User Index: 3833, Similarity: varun121, Distance: 1.0
# Test User: saphira_wydra, Top 3 Similar Users:
#    1. User Index: 5817, Similarity: bharath_sabbisetty, Distance: -0.005127832666074417
#    2. User Index: 20133, Similarity: nemishakhosa, Distance: -0.42420453587256923
#    3. User Index: 16975, Similarity: prajaktashinde7, Distance: -1.2376677948256751
# Test User: spiketospica, Top 3 Similar Users:
#    1. User Index: 1968, Similarity: ankita04, Distance: -3.2427253316706706
#    2. User Index: 6873, Similarity: Ani93Ray, Distance: -3.35894482644596
#    3. User Index: 8978, Similarity: akashmm172, Distance: -3.358982564773573
# Test User: ganesh136, Top 3 Similar Users:
#    1. User Index: 3844, Similarity: tookgre, Distance: 1.0
#    2. User Index: 4548, Similarity: rahulkrsna, Distance: 1.0
#    3. User Index: 3432, Similarity: coolbuddy24908, Distance: 0.999
# Test User: bhargavbull13, Top 3 Similar Users:
#    1. User Index: 6324, Similarity: sherry123, Distance: 0.9983
#    2. User Index: 16049, Similarity: Icey.ivy90, Distance: 0.9952
#    3. User Index: 2384, Similarity: heem2990, Distance: 0.9892
# Test User: veeace, Top 3 Similar Users:
#    1. User Index: 872, Similarity: akshaybhat11, Distance: 1.0
#    2. User Index: 135, Similarity: silverpaddy, Distance: 1.0
#    3. User Index: 822, Similarity: hrishikesh255, Distance: 1.0
# Test User: adarshbaluni, Top 3 Similar Users:
#    1. User Index: 1470, Similarity: Blastoise, Distance: -2.0014287864282236
#    2. User Index: 20138, Similarity: ahmad.saad.khan.91, Distance: -2.7457289223861356
#    3. User Index: 19796, Similarity: manasa969, Distance: -3.1264298564255277
# Test User: kousikff, Top 3 Similar Users:
#    1. User Index: 15409, Similarity: sethuram19, Distance: 0.999
#    2. User Index: 17046, Similarity: kashishwadhwa, Distance: 0.999
#    3. User Index: 370, Similarity: jhstjh, Distance: 0.9989999999999999
# Test User: rajeshrocks25, Top 3 Similar Users:
#    1. User Index: 2594, Similarity: floraS, Distance: 1.0
#    2. User Index: 718, Similarity: fountain_head, Distance: 1.0
#    3. User Index: 360, Similarity: RAB7, Distance: 1.0
# Test User: aravind_2612, Top 3 Similar Users:
#    1. User Index: 13815, Similarity: ajan1991, Distance: 1.0
#    2. User Index: 19071, Similarity: sayanroy1989, Distance: 1.0
#    3. User Index: 12506, Similarity: onusopus, Distance: 0.9999999999999999
# Test User: manojkrishs, Top 3 Similar Users:
#    1. User Index: 14586, Similarity: suh007, Distance: -4.099108354408641
#    2. User Index: 6004, Similarity: anshul.roonwal@gmail.com, Distance: -4.9160884045118864
#    3. User Index: 8986, Similarity: skyline385, Distance: -4.916106862625116
# Test User: krsh_kk1, Top 3 Similar Users:
#    1. User Index: 8096, Similarity: indianidle, Distance: 1.0
#    2. User Index: 7773, Similarity: shanki23.18, Distance: 1.0
#    3. User Index: 890, Similarity: virtuoso015, Distance: 1.0
# Test User: the green knight, Top 3 Similar Users:
#    1. User Index: 15387, Similarity: tcsjann, Distance: -0.418032439685355
#    2. User Index: 17107, Similarity: sid221991, Distance: -1.4544522810598703
#    3. User Index: 1975, Similarity: nagtharun, Distance: -2.000001499999625
# Test User: chhavigandhi, Top 3 Similar Users:
#    1. User Index: 2894, Similarity: LeeluChoudary, Distance: 0.9981999999999999
#    2. User Index: 1582, Similarity: NISHANTHVOLAM, Distance: 0.9981999999999999
#    3. User Index: 1688, Similarity: nilay7, Distance: 0.9981999999999999
# Test User: sidd.splendid, Top 3 Similar Users:
#    1. User Index: 10997, Similarity: JSP2012, Distance: 1.0
#    2. User Index: 2130, Similarity: rohannimbal, Distance: 1.0
#    3. User Index: 6566, Similarity: dywyd, Distance: 1.0
# Test User: nsitvar, Top 3 Similar Users:
#    1. User Index: 14423, Similarity: aaseemsufi, Distance: -6.072513626710096
#    2. User Index: 4490, Similarity: ameysdhaygude, Distance: -6.349448958935629
#    3. User Index: 5294, Similarity: surra87, Distance: -6.681933350400796
# Test User: madhav1351, Top 3 Similar Users:
#    1. User Index: 11161, Similarity: DamienPooh, Distance: 0.9999999999999999
#    2. User Index: 20313, Similarity: Alok1987, Distance: 0.999
#    3. User Index: 1408, Similarity: qwerty89, Distance: 0.9989999999999999
# Test User: hema26sampath, Top 3 Similar Users:
#    1. User Index: 7923, Similarity: hardik.jani, Distance: -2.324315869468484
#    2. User Index: 4844, Similarity: divya.bitragunta, Distance: -2.7487812686258453
#    3. User Index: 603, Similarity: vshukl1, Distance: -3.246085373611793
# Test User: yashvier, Top 3 Similar Users:
#    1. User Index: 14445, Similarity: arda, Distance: 0.995
#    2. User Index: 5524, Similarity: sugandhaqms, Distance: 0.9939
#    3. User Index: 10346, Similarity: machiry, Distance: 0.993
# Test User: saif.mohmd@gmail.com, Top 3 Similar Users:
#    1. User Index: 1821, Similarity: ssrpallavi, Distance: 1.0
#    2. User Index: 353, Similarity: neerajsharma20, Distance: 1.0
#    3. User Index: 1550, Similarity: pralaybiswas, Distance: 1.0
# Test User: pruthvitalluru, Top 3 Similar Users:
#    1. User Index: 9298, Similarity: sy_123, Distance: 0.998
#    2. User Index: 2472, Similarity: ujwalks22, Distance: 0.998
#    3. User Index: 15515, Similarity: saurabhjagdhane, Distance: 0.956
# Test User: agashegaurav, Top 3 Similar Users:
#    1. User Index: 7727, Similarity: naveen7, Distance: 1.0
#    2. User Index: 3415, Similarity: madhura24, Distance: 1.0
#    3. User Index: 2787, Similarity: shankhs, Distance: 1.0
# Test User: pavithra02, Top 3 Similar Users:
#    1. User Index: 70, Similarity: Cognitive, Distance: 1.0
#    2. User Index: 18281, Similarity: srikanth_027, Distance: 1.0
#    3. User Index: 9615, Similarity: oakmayura, Distance: 0.9998
# Test User: pp14, Top 3 Similar Users:
#    1. User Index: 20349, Similarity: ayush_bhatia, Distance: 1.0
#    2. User Index: 16224, Similarity: ritzy20, Distance: 1.0
#    3. User Index: 12447, Similarity: Nitish.Dixit, Distance: 1.0
# Test User: ajaypanwar092, Top 3 Similar Users:
#    1. User Index: 1141, Similarity: sudharshannv, Distance: 1.0
#    2. User Index: 15748, Similarity: Mystogan, Distance: 1.0
#    3. User Index: 17019, Similarity: greatgre, Distance: 0.9999999999999999
# Test User: dnyanraj, Top 3 Similar Users:
#    1. User Index: 1237, Similarity: ambika.v, Distance: -1.828442744691856
#    2. User Index: 1621, Similarity: akshayaiyer, Distance: -3.0017107591628855
#    3. User Index: 14263, Similarity: rakshita_nsit10, Distance: -3.2426864237178785
# Test User: push1988, Top 3 Similar Users:
#    1. User Index: 3955, Similarity: Loukya, Distance: 1.0
#    2. User Index: 803, Similarity: fawkesash, Distance: 1.0
#    3. User Index: 2854, Similarity: zeusaka, Distance: 1.0
# Test User: pratikiyer, Top 3 Similar Users:
#    1. User Index: 179, Similarity: priyancess, Distance: -0.012405057276977383
#    2. User Index: 10933, Similarity: skamble6666, Distance: -0.015369883343011148
#    3. User Index: 18935, Similarity: varunaggarwal, Distance: -1.0000999975001248
# Test User: silent.prince90, Top 3 Similar Users:
#    1. User Index: 5379, Similarity: prashant.nitrkl, Distance: -1.8291739076981464
#    2. User Index: 12070, Similarity: eggman, Distance: -5.000674962035521
#    3. User Index: 4614, Similarity: pulimon, Distance: -7.062452232416636
# Test User: milonb, Top 3 Similar Users:
#    1. User Index: 18246, Similarity: prakash86, Distance: 1.0
#    2. User Index: 9011, Similarity: RedRike, Distance: 1.0
#    3. User Index: 19296, Similarity: sanjayadhikari1989, Distance: 0.9993
# Test User: aayush251, Top 3 Similar Users:
#    1. User Index: 19856, Similarity: pcgandhi, Distance: 0.9998999999999999
#    2. User Index: 2346, Similarity: Shreyas_Bhat, Distance: 0.998
#    3. User Index: 190, Similarity: harikeshav, Distance: 0.998
# Test User: ra.ver, Top 3 Similar Users:
#    1. User Index: 14589, Similarity: piyushest, Distance: 1.0
#    2. User Index: 11952, Similarity: icecool15, Distance: 0.9994
#    3. User Index: 17774, Similarity: varun6061, Distance: 0.999
# Test User: abiramib, Top 3 Similar Users:
#    1. User Index: 7658, Similarity: Simhamadda, Distance: 1.0
#    2. User Index: 4148, Similarity: vinay.melgiri, Distance: 1.0
#    3. User Index: 6441, Similarity: illusionist.h1, Distance: 1.0
# Test User: grevan, Top 3 Similar Users:
#    1. User Index: 3419, Similarity: Zondek123, Distance: 1.0
#    2. User Index: 1984, Similarity: DMJBandekar, Distance: 1.0
#    3. User Index: 4059, Similarity: charlatan, Distance: 1.0
# Test User: harshal.rao, Top 3 Similar Users:
#    1. User Index: 3955, Similarity: Loukya, Distance: 1.0
#    2. User Index: 803, Similarity: fawkesash, Distance: 1.0
#    3. User Index: 2854, Similarity: zeusaka, Distance: 1.0
# Test User: vijaykumar.koppad, Top 3 Similar Users:
#    1. User Index: 17224, Similarity: harunrashid, Distance: 0.999
#    2. User Index: 7298, Similarity: ram@georgia, Distance: 0.998
#    3. User Index: 13908, Similarity: sanjeev89, Distance: 0.998
# Test User: avik88, Top 3 Similar Users:
#    1. User Index: 20437, Similarity: prasadium, Distance: 1.0
#    2. User Index: 106, Similarity: MADHUDARL, Distance: 0.9979999999999999
#    3. User Index: 8513, Similarity: nayanap, Distance: 0.9917
# Test User: aman_chanana, Top 3 Similar Users:
#    1. User Index: 9555, Similarity: Colossal Dud(e), Distance: 1.0
#    2. User Index: 6870, Similarity: theincredibleguy, Distance: 0.9991000000000001
#    3. User Index: 1786, Similarity: hue054, Distance: 0.999
# Test User: LMD, Top 3 Similar Users:
#    1. User Index: 8349, Similarity: sagarkamat, Distance: 1.0
#    2. User Index: 2979, Similarity: james_sawyer, Distance: 1.0
#    3. User Index: 7107, Similarity: Prof.Moriarty, Distance: 1.0
# Test User: nitin0746, Top 3 Similar Users:
#    1. User Index: 14120, Similarity: prjwl7891, Distance: 1.0
#    2. User Index: 1013, Similarity: Srinath Narayan, Distance: 1.0
#    3. User Index: 104, Similarity: darkranger, Distance: 0.9980000000000001
# Test User: tejaswikgp, Top 3 Similar Users:
#    1. User Index: 12929, Similarity: Soundofmusic, Distance: 0.9994000000000001
#    2. User Index: 4131, Similarity: wolverinex, Distance: 0.999
#    3. User Index: 654, Similarity: NPuri, Distance: 0.998
# Test User: vinay90, Top 3 Similar Users:
#    1. User Index: 11726, Similarity: meghna_17, Distance: 1.0
#    2. User Index: 18625, Similarity: isildur, Distance: 0.9999
#    3. User Index: 14968, Similarity: anjan1989, Distance: 0.999
# Test User: manan24, Top 3 Similar Users:
#    1. User Index: 17402, Similarity: CSP007CHINMAY, Distance: 1.0
#    2. User Index: 2111, Similarity: Nagarjuna123, Distance: 0.999
#    3. User Index: 1644, Similarity: Nirvana075, Distance: 0.999
# Test User: ram@georgia, Top 3 Similar Users:
#    1. User Index: 18171, Similarity: gaut2112, Distance: 1.0
#    2. User Index: 3289, Similarity: chabhishek, Distance: 1.0
#    3. User Index: 7942, Similarity: sg_bodhe, Distance: 1.0
# Test User: ashu3000, Top 3 Similar Users:
#    1. User Index: 8392, Similarity: archana.muralimohan, Distance: 0.9995999999999999
#    2. User Index: 6774, Similarity: sagarv21, Distance: 0.9984
#    3. User Index: 4093, Similarity: vidyadharreddy23, Distance: 0.998
# Test User: kedaritheja, Top 3 Similar Users:
#    1. User Index: 10448, Similarity: Raiden, Distance: 0.9998999999999999
#    2. User Index: 10395, Similarity: wadz007, Distance: 0.9990000000000001
#    3. User Index: 18550, Similarity: sunitj, Distance: 0.999
# Test User: SudharsanS, Top 3 Similar Users:
#    1. User Index: 13929, Similarity: abhisek09, Distance: 1.0
#    2. User Index: 2876, Similarity: Dark Knight, Distance: 1.0
#    3. User Index: 5972, Similarity: ramendra09, Distance: 1.0
# Test User: aseshank2011, Top 3 Similar Users:
#    1. User Index: 8551, Similarity: harishankarK, Distance: 1.0
#    2. User Index: 2452, Similarity: abhishek_saini, Distance: 1.0
#    3. User Index: 3720, Similarity: ravi00, Distance: 1.0
# Test User: v_s, Top 3 Similar Users:
#    1. User Index: 4058, Similarity: raVer, Distance: 1.0
#    2. User Index: 12715, Similarity: Goldenabcd, Distance: 0.9995999999999999
#    3. User Index: 5408, Similarity: 22sanyogita, Distance: 0.9994
# Test User: divyeshhh, Top 3 Similar Users:
#    1. User Index: 13222, Similarity: Murugapandian, Distance: 0.9999999999999999
#    2. User Index: 17172, Similarity: himank, Distance: 0.9990000000000001
#    3. User Index: 6249, Similarity: nitya103, Distance: 0.9990000000000001
# Test User: uvrambo9, Top 3 Similar Users:
#    1. User Index: 5081, Similarity: monic1992, Distance: 0.9999999999999999
#    2. User Index: 13489, Similarity: nimisha, Distance: 0.9993
#    3. User Index: 181, Similarity: mechengg, Distance: 0.9982
# Test User: mugmv, Top 3 Similar Users:
#    1. User Index: 8957, Similarity: raghuramparthasarathy, Distance: 0.993
#    2. User Index: 13654, Similarity: hardik_surana, Distance: 0.977
#    3. User Index: 13125, Similarity: girish34, Distance: 0.971
# Test User: ready4it, Top 3 Similar Users:
#    1. User Index: 3493, Similarity: surabhijain56, Distance: 1.0
#    2. User Index: 566, Similarity: gautamnaik, Distance: 1.0
#    3. User Index: 3185, Similarity: kirankn, Distance: 1.0
# Test User: shr8055, Top 3 Similar Users:
#    1. User Index: 2386, Similarity: mbharathit, Distance: 1.0
#    2. User Index: 1751, Similarity: psaikiran2890, Distance: 1.0
#    3. User Index: 1711, Similarity: hi_rahul, Distance: 1.0
# Test User: sheronpaul, Top 3 Similar Users:
#    1. User Index: 2326, Similarity: saijaddhuka, Distance: 1.0
#    2. User Index: 2020, Similarity: krunal24787, Distance: 1.0
#    3. User Index: 302, Similarity: shradhaa, Distance: 1.0
# Test User: kumar198, Top 3 Similar Users:
#    1. User Index: 17426, Similarity: ac@comp, Distance: 0.997
#    2. User Index: 20390, Similarity: bsniv24, Distance: -0.0005118689950658339
#    3. User Index: 16369, Similarity: dtpandey48, Distance: -0.0025173315210067493
# Test User: arthy.ramamurthy, Top 3 Similar Users:
#    1. User Index: 789, Similarity: pradeep_mis, Distance: 1.0
#    2. User Index: 619, Similarity: surendeepak, Distance: 1.0
#    3. User Index: 235, Similarity: Ankit2010, Distance: 1.0
# Test User: krizh1990, Top 3 Similar Users:
#    1. User Index: 452, Similarity: kiranks, Distance: 1.0
#    2. User Index: 298, Similarity: Manish Mahawar, Distance: 1.0
#    3. User Index: 171, Similarity: S.C.Harish, Distance: 1.0
# Test User: soumya0985, Top 3 Similar Users:
#    1. User Index: 4576, Similarity: karan.tech9, Distance: 1.0
#    2. User Index: 3360, Similarity: gundaswaraj, Distance: 1.0
#    3. User Index: 3385, Similarity: indra91, Distance: 1.0
# Test User: coolmetal, Top 3 Similar Users:
#    1. User Index: 5515, Similarity: ravishankar501, Distance: 1.0
#    2. User Index: 245, Similarity: mscs_2011, Distance: 1.0
#    3. User Index: 157, Similarity: sagar1410, Distance: 1.0
# Test User: floraS, Top 3 Similar Users:
#    1. User Index: 2149, Similarity: fountain_head, Distance: 1.0
#    2. User Index: 13934, Similarity: shaheel, Distance: 1.0
#    3. User Index: 567, Similarity: ajita2011, Distance: 0.9930000000000001
# Test User: nasir795, Top 3 Similar Users:
#    1. User Index: 17083, Similarity: ritwikgiri, Distance: 1.0
#    2. User Index: 8868, Similarity: karthik.krish1, Distance: 1.0
#    3. User Index: 1782, Similarity: kshankar1993, Distance: 1.0
# Test User: SakuraHiwatari, Top 3 Similar Users:
#    1. User Index: 1359, Similarity: shaily_gre, Distance: 0.9999
#    2. User Index: 17601, Similarity: nma1234, Distance: 0.9992
#    3. User Index: 3849, Similarity: ganeshskudva1986, Distance: 0.9984000000000001
# Test User: Sid_M, Top 3 Similar Users:
#    1. User Index: 895, Similarity: vadkhs, Distance: 1.0
#    2. User Index: 663, Similarity: attidood, Distance: 1.0
#    3. User Index: 661, Similarity: shravanvijay, Distance: 1.0
# Test User: Anurag_Gaggar, Top 3 Similar Users:
#    1. User Index: 20324, Similarity: xyz2121989, Distance: -6.483367156567957
#    2. User Index: 19528, Similarity: karan1337, Distance: -6.9372615554736505
#    3. User Index: 13339, Similarity: kartikaygarg, Distance: -8.949882222921033
# Test User: rahu67, Top 3 Similar Users:
#    1. User Index: 3493, Similarity: surabhijain56, Distance: 1.0
#    2. User Index: 566, Similarity: gautamnaik, Distance: 1.0
#    3. User Index: 3185, Similarity: kirankn, Distance: 1.0
# Test User: vaidya88, Top 3 Similar Users:
#    1. User Index: 12415, Similarity: river_in_the_sky, Distance: 1.0
#    2. User Index: 4859, Similarity: devlinac, Distance: 1.0
#    3. User Index: 1534, Similarity: swapnilkothe, Distance: 0.999
# Test User: reverie, Top 3 Similar Users:
#    1. User Index: 18215, Similarity: karanshah89, Distance: -1.236111804002653
#    2. User Index: 4665, Similarity: sri_005, Distance: -2.0001306638211607
#    3. User Index: 15563, Similarity: adityapurandare, Distance: -2.00030815084051
# Test User: aravinds12, Top 3 Similar Users:
#    1. User Index: 3177, Similarity: MaximaMinima, Distance: 1.0
#    2. User Index: 1100, Similarity: sharath_shreet, Distance: 1.0
#    3. User Index: 1554, Similarity: alwaysap, Distance: 1.0
# Test User: JayadevP, Top 3 Similar Users:
#    1. User Index: 18546, Similarity: wazza, Distance: 1.0
#    2. User Index: 13919, Similarity: kesari, Distance: 1.0
#    3. User Index: 5357, Similarity: Gurpreet1928, Distance: 0.9999
# Test User: akshayphadke, Top 3 Similar Users:
#    1. User Index: 7831, Similarity: LMD, Distance: 1.0
#    2. User Index: 5796, Similarity: AbhinandanPatil, Distance: 1.0
#    3. User Index: 2150, Similarity: write.to.sparsh.raj, Distance: 1.0
# Test User: Harsh Acharya, Top 3 Similar Users:
#    1. User Index: 2331, Similarity: keepguessin, Distance: 1.0
#    2. User Index: 1041, Similarity: Arztin, Distance: 1.0
#    3. User Index: 970, Similarity: KingJames, Distance: 1.0
# Test User: pradnya1605, Top 3 Similar Users:
#    1. User Index: 4026, Similarity: JollyD, Distance: 1.0
#    2. User Index: 2802, Similarity: Swati subhedar, Distance: 1.0
#    3. User Index: 2881, Similarity: iPwNuDwN, Distance: 1.0
# Test User: navoriion, Top 3 Similar Users:
#    1. User Index: 5497, Similarity: jtshapir, Distance: 1.0
#    2. User Index: 2083, Similarity: ankit_talesara, Distance: 1.0
#    3. User Index: 4315, Similarity: jaimin_1234, Distance: 1.0
# Test User: shivangibansal92, Top 3 Similar Users:
#    1. User Index: 14219, Similarity: Bhawani, Distance: 1.0
#    2. User Index: 2048, Similarity: prateekgt, Distance: 1.0
#    3. User Index: 4414, Similarity: obuli.karthik, Distance: 1.0
# Test User: nitreddy, Top 3 Similar Users:
#    1. User Index: 14847, Similarity: Sesshomaru, Distance: 1.0
#    2. User Index: 4650, Similarity: riyaa, Distance: 1.0
#    3. User Index: 6076, Similarity: albus123, Distance: 0.9990000000000001
# Test User: sudhanshu.bhatt, Top 3 Similar Users:
#    1. User Index: 16777, Similarity: kasyapys, Distance: 1.0
#    2. User Index: 4997, Similarity: mayank_sinha, Distance: 1.0
#    3. User Index: 12730, Similarity: rajkiranb, Distance: 0.9994999999999999
# Test User: apurva170988, Top 3 Similar Users:
#    1. User Index: 18263, Similarity: fab4regas, Distance: -1.00000899997975
#    2. User Index: 7442, Similarity: apds1088, Distance: -1.000024999843752
#    3. User Index: 10285, Similarity: KS782, Distance: -1.0011219353152874
# Test User: pooh174, Top 3 Similar Users:
#    1. User Index: 10384, Similarity: Kurukunda Venkata Neehar, Distance: 0.998
#    2. User Index: 18240, Similarity: venkatavijay, Distance: 0.996
#    3. User Index: 14909, Similarity: devlinac, Distance: 0.994
# Test User: sudhakar chatrathi, Top 3 Similar Users:
#    1. User Index: 19014, Similarity: TheGodfather, Distance: 0.998
#    2. User Index: 330, Similarity: pradeep, Distance: 0.998
#    3. User Index: 20422, Similarity: gokul_b, Distance: 0.9964
# Test User: diha, Top 3 Similar Users:
#    1. User Index: 5567, Similarity: jaanu3k, Distance: 1.0
#    2. User Index: 1035, Similarity: abrishu, Distance: 1.0
#    3. User Index: 2923, Similarity: harsh_singh, Distance: 1.0
# Test User: niketkandya, Top 3 Similar Users:
#    1. User Index: 7593, Similarity: herat, Distance: 1.0
#    2. User Index: 3293, Similarity: NehaTadimeti, Distance: 0.9990000000000001
#    3. User Index: 213, Similarity: confucius, Distance: 0.999
# Test User: gauthamramchandran, Top 3 Similar Users:
#    1. User Index: 10432, Similarity: kishan1890, Distance: 1.0
#    2. User Index: 16181, Similarity: raj.65, Distance: 1.0
#    3. User Index: 10243, Similarity: shriniket.kale, Distance: 0.9995
# Test User: anoop_2k2002, Top 3 Similar Users:
#    1. User Index: 10366, Similarity: devdar, Distance: 1.0
#    2. User Index: 6256, Similarity: yuvareddy, Distance: 1.0
#    3. User Index: 7113, Similarity: vinayak.shenoy, Distance: 1.0
# Test User: dilipbsr, Top 3 Similar Users:
#    1. User Index: 8800, Similarity: sankethks, Distance: 0.9999
#    2. User Index: 4512, Similarity: shashankraj00, Distance: 0.9999
#    3. User Index: 4415, Similarity: xxgeekxx, Distance: 0.9999
# Test User: pulkitsachdeva, Top 3 Similar Users:
#    1. User Index: 4690, Similarity: dev997, Distance: -0.4159947033799243
#    2. User Index: 13724, Similarity: n4niranjan, Distance: -0.4165888606084689
#    3. User Index: 19078, Similarity: debanikl, Distance: -1.4495977220760148
# Test User: IamAchilles, Top 3 Similar Users:
#    1. User Index: 6562, Similarity: axis22, Distance: 1.0
#    2. User Index: 5743, Similarity: prax@87, Distance: 1.0
#    3. User Index: 3191, Similarity: msrockzzz, Distance: 1.0
# Test User: manpreet.singh, Top 3 Similar Users:
#    1. User Index: 10340, Similarity: ravshnkr, Distance: 1.0
#    2. User Index: 5197, Similarity: a2306, Distance: 1.0
#    3. User Index: 3902, Similarity: pramod.natraj, Distance: 1.0
# Test User: meghaddn, Top 3 Similar Users:
#    1. User Index: 17563, Similarity: anishparikh, Distance: 0.9990000000000001
#    2. User Index: 2963, Similarity: prem.avn, Distance: 0.9990000000000001
#    3. User Index: 4915, Similarity: namitp, Distance: 0.999
# Test User: kanap008, Top 3 Similar Users:
#    1. User Index: 18914, Similarity: rahul8590, Distance: 1.0
#    2. User Index: 10032, Similarity: skittles99, Distance: 1.0
#    3. User Index: 7148, Similarity: prashant.bhardwaj, Distance: 0.998
# Test User: mickeyv, Top 3 Similar Users:
#    1. User Index: 17939, Similarity: kleptomaniac, Distance: 0.99
#    2. User Index: 771, Similarity: vick4523zf, Distance: 0.9400000000000001
#    3. User Index: 11070, Similarity: GREDummy007, Distance: 0.8700000000000001
# Test User: knat, Top 3 Similar Users:
#    1. User Index: 11798, Similarity: there, Distance: 1.0
#    2. User Index: 1563, Similarity: chirayu.diwan09, Distance: 1.0
#    3. User Index: 2576, Similarity: mayank.dce2k7, Distance: 1.0
# Test User: thiru650, Top 3 Similar Users:
#    1. User Index: 1406, Similarity: madhusudhan2310, Distance: 1.0
#    2. User Index: 1171, Similarity: shango, Distance: 1.0
#    3. User Index: 1069, Similarity: hh25, Distance: 1.0
# Test User: mayankdhull, Top 3 Similar Users:
#    1. User Index: 20627, Similarity: PrashantNigam, Distance: -0.41840791029943136
#    2. User Index: 10530, Similarity: sarveshb707, Distance: -0.41880090217056165
#    3. User Index: 6528, Similarity: bajajkaran23, Distance: -1.0
# Test User: ashish.r.gupta193, Top 3 Similar Users:
#    1. User Index: 19350, Similarity: sagar23, Distance: 1.0
#    2. User Index: 8361, Similarity: srk108, Distance: 1.0
#    3. User Index: 3512, Similarity: sohangvvs92, Distance: 0.9999999999999999
# Test User: mgalva, Top 3 Similar Users:
#    1. User Index: 5443, Similarity: sivawebmaster, Distance: 1.0
#    2. User Index: 221, Similarity: siric, Distance: 1.0
#    3. User Index: 4347, Similarity: jagsmaster, Distance: 1.0
# Test User: chakra.jagan, Top 3 Similar Users:
#    1. User Index: 3832, Similarity: poorvirk, Distance: 1.0
#    2. User Index: 20136, Similarity: manojpanguluru, Distance: 1.0
#    3. User Index: 528, Similarity: Ramya Sri Kanuparti, Distance: 0.999
# Test User: kapilsharma, Top 3 Similar Users:
#    1. User Index: 5233, Similarity: kepai91, Distance: 0.83
#    2. User Index: 15567, Similarity: mihir007007, Distance: -2.0077086029068707
#    3. User Index: 18259, Similarity: bhargav_sg, Distance: -3.2494234903101855
# Test User: utkarsh deshmukh, Top 3 Similar Users:
#    1. User Index: 1456, Similarity: grandhi_sarath, Distance: 1.0
#    2. User Index: 18013, Similarity: Dsr_123, Distance: 0.997
#    3. User Index: 18253, Similarity: Moddu, Distance: 0.995
# Test User: Bhaavyaa, Top 3 Similar Users:
#    1. User Index: 9768, Similarity: jamg, Distance: 1.0
#    2. User Index: 2722, Similarity: shyam22, Distance: 1.0
#    3. User Index: 793, Similarity: grefall09, Distance: 1.0
# Test User: shruti3790, Top 3 Similar Users:
#    1. User Index: 4586, Similarity: girishba, Distance: 1.0
#    2. User Index: 2549, Similarity: rachanarao, Distance: 1.0
#    3. User Index: 2674, Similarity: tarunparwani, Distance: 1.0
# Test User: abhicool_gre, Top 3 Similar Users:
#    1. User Index: 11326, Similarity: admseeker11, Distance: 1.0
#    2. User Index: 14462, Similarity: kjayasurya, Distance: 0.9991000000000001
#    3. User Index: 9098, Similarity: diehardfighter, Distance: 0.9975
# Test User: aishwaryal-cse15, Top 3 Similar Users:
#    1. User Index: 5831, Similarity: abhishekj200, Distance: 0.999
#    2. User Index: 12767, Similarity: kevinjj5, Distance: 0.989
#    3. User Index: 11280, Similarity: TanyaJain, Distance: 0.989
# Test User: siddharth_55, Top 3 Similar Users:
#    1. User Index: 9637, Similarity: ranjeshgre, Distance: 1.0
#    2. User Index: 15222, Similarity: bidda2310, Distance: 1.0
#    3. User Index: 18357, Similarity: adarsh4192, Distance: 0.9994999999999999
# Test User: Pursue_MSINMIS, Top 3 Similar Users:
#    1. User Index: 274, Similarity: pavann.n, Distance: 1.0
#    2. User Index: 13271, Similarity: sanjayc, Distance: 1.0
#    3. User Index: 17934, Similarity: sharma.bhawana, Distance: 0.9960000000000001
# Test User: blitzranjith, Top 3 Similar Users:
#    1. User Index: 4093, Similarity: vidyadharreddy23, Distance: 1.0
#    2. User Index: 18531, Similarity: kondashailesh, Distance: 1.0
#    3. User Index: 14901, Similarity: tharunkanth@gmial.com, Distance: 0.9991
# Test User: ananya123, Top 3 Similar Users:
#    1. User Index: 14496, Similarity: Hari Anandh, Distance: 1.0
#    2. User Index: 8662, Similarity: chetu.44ever, Distance: 1.0
#    3. User Index: 10253, Similarity: ssam123, Distance: 1.0
# Test User: Karthik_IBMGET, Top 3 Similar Users:
#    1. User Index: 16048, Similarity: Aparna15, Distance: 0.9329999999999998
#    2. User Index: 9737, Similarity: karthiksaman, Distance: 0.909
#    3. User Index: 18666, Similarity: yashborghate, Distance: 0.863
# Test User: sohailpuri, Top 3 Similar Users:
#    1. User Index: 5250, Similarity: Philanderer1310, Distance: 0.9990000000000001
#    2. User Index: 3163, Similarity: muraliravi, Distance: 0.9990000000000001
#    3. User Index: 2630, Similarity: deeptihari, Distance: 0.9990000000000001
# Test User: tejas.rox, Top 3 Similar Users:
#    1. User Index: 5338, Similarity: bhavin_mankad, Distance: 0.99939
#    2. User Index: 6502, Similarity: nish2292, Distance: 0.99859
#    3. User Index: 7458, Similarity: pranav_s, Distance: 0.9975900000000001
# Test User: styagi, Top 3 Similar Users:
#    1. User Index: 19007, Similarity: NooBee123, Distance: 1.0
#    2. User Index: 6644, Similarity: vharish23, Distance: 1.0
#    3. User Index: 8511, Similarity: radi, Distance: 0.9992000000000001
# Test User: herle89, Top 3 Similar Users:
#    1. User Index: 6337, Similarity: dev62, Distance: 1.0
#    2. User Index: 12843, Similarity: rakems, Distance: 0.9998
#    3. User Index: 17887, Similarity: anudhans, Distance: 0.9988
# Test User: kasyapys, Top 3 Similar Users:
#    1. User Index: 17548, Similarity: subhashish.dash, Distance: 1.0
#    2. User Index: 19214, Similarity: sabeer_nitb, Distance: 0.9994999999999999
#    3. User Index: 2379, Similarity: nishikanth, Distance: 0.998
# Test User: cs2013, Top 3 Similar Users:
#    1. User Index: 12337, Similarity: nikunjyadav, Distance: 0.999
#    2. User Index: 18371, Similarity: geminishru, Distance: 0.999
#    3. User Index: 8313, Similarity: Sreenivaas, Distance: 0.998
# Test User: AmeyaVilankar, Top 3 Similar Users:
#    1. User Index: 17672, Similarity: Aish1993, Distance: 0.9995999999999999
#    2. User Index: 8555, Similarity: sanavaali, Distance: 0.9995999999999999
#    3. User Index: 17634, Similarity: munirpatel, Distance: 0.9995999999999999
# Test User: shruti.gautam, Top 3 Similar Users:
#    1. User Index: 9940, Similarity: anujashah, Distance: 0.9975
#    2. User Index: 15899, Similarity: vignesh04, Distance: 0.9974999999999999
#    3. User Index: 12583, Similarity: Daisycrystal, Distance: 0.996
# Test User: egunner, Top 3 Similar Users:
#    1. User Index: 2647, Similarity: Hridheek, Distance: 1.0
#    2. User Index: 1405, Similarity: koustubhkulk, Distance: 1.0
#    3. User Index: 1608, Similarity: AdiBhat, Distance: 1.0
# Test User: bharath3003, Top 3 Similar Users:
#    1. User Index: 3721, Similarity: Dragon2000, Distance: 0.9975
#    2. User Index: 16252, Similarity: lamyaa, Distance: 0.995
#    3. User Index: 6809, Similarity: siddta, Distance: 0.9824999999999999
# Test User: vihi1993, Top 3 Similar Users:
#    1. User Index: 2943, Similarity: lokkeshkhatri, Distance: 0.97
#    2. User Index: 3048, Similarity: Renukashan, Distance: 0.1725
#    3. User Index: 1277, Similarity: abhiramee08b021, Distance: 0.16299999999999992
# Test User: subbareddy, Top 3 Similar Users:
#    1. User Index: 10041, Similarity: venzidane89, Distance: 1.0
#    2. User Index: 3032, Similarity: sri007, Distance: 1.0
#    3. User Index: 4587, Similarity: Aishwarya23, Distance: 1.0
# Test User: tstrinadhreddy, Top 3 Similar Users:
#    1. User Index: 8145, Similarity: akshayemediratta, Distance: 0.85
#    2. User Index: 19894, Similarity: abhishekh, Distance: -2.4641016151377544
#    3. User Index: 19748, Similarity: dsrscore2, Distance: -3.4721450110657193
# Test User: rangudu, Top 3 Similar Users:
#    1. User Index: 9133, Similarity: VishnuVasanth, Distance: -11.409673686282005
#    2. User Index: 18903, Similarity: parth1590, Distance: -16.05923668427166
#    3. User Index: 12919, Similarity: vidhu.0007, Distance: -16.748686599295173
# Test User: mahiz, Top 3 Similar Users:
#    1. User Index: 13340, Similarity: Sagarika Raj, Distance: 0.3999999999999999
#    2. User Index: 3457, Similarity: studious_ukv, Distance: 0.3949999999999999
#    3. User Index: 10, Similarity: kavithav, Distance: 0.3599999999999999
# Test User: marvin_paranoid_android, Top 3 Similar Users:
#    1. User Index: 2627, Similarity: akshaylive, Distance: 0.999
#    2. User Index: 10737, Similarity: prak5190, Distance: 0.9989999999999999
#    3. User Index: 6732, Similarity: nish2292, Distance: 0.9989999999999999
# Test User: TargetMS, Top 3 Similar Users:
#    1. User Index: 10173, Similarity: varunm88, Distance: 1.0
#    2. User Index: 7949, Similarity: ckmnitr, Distance: 0.999
#    3. User Index: 5348, Similarity: ritish01, Distance: 0.999
# Test User: rritambhar, Top 3 Similar Users:
#    1. User Index: 10344, Similarity: crazylife, Distance: 1.0
#    2. User Index: 580, Similarity: whiz_phoenix, Distance: 1.0
#    3. User Index: 4628, Similarity: onlysujay, Distance: 1.0
# Test User: chirag_lathia, Top 3 Similar Users:
#    1. User Index: 2125, Similarity: karishmaktandon, Distance: 1.0
#    2. User Index: 1871, Similarity: priyankasehgal25, Distance: 1.0
#    3. User Index: 2135, Similarity: nkl360, Distance: 1.0
# Test User: ameya_notworthit, Top 3 Similar Users:
#    1. User Index: 17102, Similarity: kashre001, Distance: 0.9980000000000001
#    2. User Index: 1637, Similarity: rohitr, Distance: 0.998
#    3. User Index: 11321, Similarity: scgre, Distance: 0.993
# Test User: vignesh_shenoy, Top 3 Similar Users:
#    1. User Index: 17675, Similarity: re@per, Distance: 0.999
#    2. User Index: 20242, Similarity: todomscs, Distance: 0.998
#    3. User Index: 402, Similarity: avijitgupta, Distance: 0.997
# Test User: off2usa2011, Top 3 Similar Users:
#    1. User Index: 17720, Similarity: neeliyer, Distance: 1.0
#    2. User Index: 3015, Similarity: astronuatricky, Distance: 0.9990000000000001
#    3. User Index: 5483, Similarity: vivek singla, Distance: 0.9990000000000001
# Test User: abhiroop11, Top 3 Similar Users:
#    1. User Index: 16204, Similarity: ankitdave, Distance: 0.998
#    2. User Index: 13549, Similarity: piscianemperor, Distance: 0.9978
#    3. User Index: 10385, Similarity: sayaliw, Distance: 0.9970000000000001
# Test User: nikhil121, Top 3 Similar Users:
#    1. User Index: 2109, Similarity: apoorva.r.g, Distance: 1.0
#    2. User Index: 933, Similarity: deepikaagarwal, Distance: 1.0
#    3. User Index: 602, Similarity: ramkrishna2910, Distance: 1.0
# Test User: iqbalnit, Top 3 Similar Users:
#    1. User Index: 8778, Similarity: ismailm, Distance: -9.00067277736853
#    2. User Index: 7583, Similarity: smishra84, Distance: -9.630363305174475
#    3. User Index: 1434, Similarity: smishra84, Distance: -9.630363305174475
# Test User: Aishwarya.89, Top 3 Similar Users:
#    1. User Index: 867, Similarity: yajursharma, Distance: 1.0
#    2. User Index: 1458, Similarity: ajitumale27, Distance: 1.0
#    3. User Index: 174, Similarity: Bhargav_27, Distance: 1.0
# Test User: jaswinivj, Top 3 Similar Users:
#    1. User Index: 7688, Similarity: kirthiaparna, Distance: 1.0
#    2. User Index: 19575, Similarity: architnandi, Distance: 0.9990000000000001
#    3. User Index: 14279, Similarity: arun7sampath, Distance: 0.999
# Test User: girish.shekhar, Top 3 Similar Users:
#    1. User Index: 19919, Similarity: pavithra02, Distance: 0.9984999999999999
#    2. User Index: 12750, Similarity: Cognitive, Distance: 0.9984999999999999
#    3. User Index: 4210, Similarity: newbrow, Distance: 0.9974999999999999
# Test User: aramchan, Top 3 Similar Users:
#    1. User Index: 5078, Similarity: BhavyaJ, Distance: 1.0
#    2. User Index: 5028, Similarity: viraj071, Distance: 1.0
#    3. User Index: 4738, Similarity: visheshtalreja, Distance: 1.0
# Test User: Annie.Utah, Top 3 Similar Users:
#    1. User Index: 96, Similarity: joshi, Distance: 1.0
#    2. User Index: 4176, Similarity: muraliavarma, Distance: 0.999
#    3. User Index: 16444, Similarity: nitit, Distance: 0.9980000000000001
# Test User: abab, Top 3 Similar Users:
#    1. User Index: 18000, Similarity: shallimeetyou, Distance: 1.0
#    2. User Index: 7624, Similarity: hemanths90, Distance: 0.9992
#    3. User Index: 1149, Similarity: k.anudeep77, Distance: 0.999
# Test User: Ripudaman0123, Top 3 Similar Users:
#    1. User Index: 12579, Similarity: MIS_Grad, Distance: 0.9998
#    2. User Index: 7919, Similarity: jawan_cs, Distance: 0.998
#    3. User Index: 4643, Similarity: sangeetav, Distance: 0.996
# Test User: Dream-Catcher, Top 3 Similar Users:
#    1. User Index: 3452, Similarity: devbrothers, Distance: 1.0
#    2. User Index: 1664, Similarity: abha.1012, Distance: 1.0
#    3. User Index: 2190, Similarity: mayu.pb07@gmail.com, Distance: 1.0
# Test User: Hapchap, Top 3 Similar Users:
#    1. User Index: 872, Similarity: akshaybhat11, Distance: 1.0
#    2. User Index: 135, Similarity: silverpaddy, Distance: 1.0
#    3. User Index: 822, Similarity: hrishikesh255, Distance: 1.0
# Test User: ra.ver, Top 3 Similar Users:
#    1. User Index: 15019, Similarity: ravitejaputta, Distance: 1.0
#    2. User Index: 14480, Similarity: vktarigopula, Distance: 0.9970000000000001
#    3. User Index: 13739, Similarity: uday012003, Distance: 0.9970000000000001
# Test User: gre.niks, Top 3 Similar Users:
#    1. User Index: 8278, Similarity: pranamib, Distance: 0.999
#    2. User Index: 1127, Similarity: nbidyanta, Distance: 0.998
#    3. User Index: 7306, Similarity: ramyaworma, Distance: 0.997
# Test User: harneet1983, Top 3 Similar Users:
#    1. User Index: 5952, Similarity: nidhishetty, Distance: 0.999
#    2. User Index: 5967, Similarity: navneet_5189, Distance: 0.997
#    3. User Index: 166, Similarity: nehagoel17, Distance: 0.997
# Test User: hyndavi, Top 3 Similar Users:
#    1. User Index: 8101, Similarity: balakrish, Distance: 0.9998999999999999
#    2. User Index: 12423, Similarity: parthatripathy, Distance: 0.9997
#    3. User Index: 12264, Similarity: molsi, Distance: 0.9992999999999999
# Test User: adarshve, Top 3 Similar Users:
#    1. User Index: 17336, Similarity: gautamsood23, Distance: 0.999
#    2. User Index: 9, Similarity: aditya0901, Distance: 0.999
#    3. User Index: 12261, Similarity: preetammshetty, Distance: 0.9965
# Test User: karteek444, Top 3 Similar Users:
#    1. User Index: 13423, Similarity: Krish, Distance: 0.999
#    2. User Index: 758, Similarity: powerpack555, Distance: 0.999
#    3. User Index: 10753, Similarity: vikram630, Distance: 0.999
# Test User: gauravbasu98, Top 3 Similar Users:
#    1. User Index: 2716, Similarity: mayank_sinha, Distance: 1.0
#    2. User Index: 4156, Similarity: ashokgre, Distance: 0.9994999999999999
#    3. User Index: 6975, Similarity: avijit2403, Distance: 0.9989999999999999
# Test User: jvgvjg, Top 3 Similar Users:
#    1. User Index: 15865, Similarity: sandyridgeracer, Distance: -1.237175934074028
#    2. User Index: 13633, Similarity: Never_Had_Wings, Distance: -1.4495515426297931
#    3. User Index: 5571, Similarity: IVB, Distance: -1.6458021392386848
# Test User: amrkap, Top 3 Similar Users:
#    1. User Index: 13848, Similarity: eduyashu, Distance: 0.9999
#    2. User Index: 11146, Similarity: hpaidipa, Distance: 0.9999
#    3. User Index: 997, Similarity: utellme90, Distance: 0.9999
# Test User: BharathManne, Top 3 Similar Users:
#    1. User Index: 2645, Similarity: snp88, Distance: 1.0
#    2. User Index: 1213, Similarity: vigneshvijay, Distance: 1.0
#    3. User Index: 1884, Similarity: rahultn, Distance: 1.0
# Test User: adityagupta, Top 3 Similar Users:
#    1. User Index: 14173, Similarity: moniblue, Distance: 1.0
#    2. User Index: 17752, Similarity: Disasterpiece, Distance: 0.99
#    3. User Index: 12482, Similarity: Prabhu23, Distance: 0.99
# Test User: lakshya_bhagat, Top 3 Similar Users:
#    1. User Index: 10041, Similarity: venzidane89, Distance: 1.0
#    2. User Index: 3032, Similarity: sri007, Distance: 1.0
#    3. User Index: 4587, Similarity: Aishwarya23, Distance: 1.0
# Test User: kondashailesh, Top 3 Similar Users:
#    1. User Index: 12655, Similarity: sikhpoint, Distance: 0.9981
#    2. User Index: 1932, Similarity: hardikshah003, Distance: 0.997
#    3. User Index: 3859, Similarity: chirayu.diwan09, Distance: 0.997
# Test User: sri_91, Top 3 Similar Users:
#    1. User Index: 9030, Similarity: aksh.th, Distance: 1.0
#    2. User Index: 16452, Similarity: narradharani, Distance: 1.0
# ...
# Test User: alekhya14, Top 3 Similar Users:
#    1. User Index: 10983, Similarity: dsidpal, Distance: 0.9996000000000002
#    2. User Index: 1552, Similarity: anr007, Distance: 0.9996
#    3. User Index: 3174, Similarity: gokullu, Distance: 0.9996
# Test User: agb89, Top 3 Similar Users:
#    1. User Index: 20507, Similarity: MaverickAC, Distance: 0.994
#    2. User Index: 12595, Similarity: aloksh589, Distance: 0.99
#    3. User Index: 16630, Similarity: sajeevgulyani, Distance: 0.989
# Test User: kjsanjay, Top 3 Similar Users:
#    1. User Index: 6902, Similarity: GautamMadaan, Distance: 1.0
#    2. User Index: 3308, Similarity: apandey, Distance: 1.0
#    3. User Index: 819, Similarity: sidfloyd, Distance: 1.0
# Test User: Satish#, Top 3 Similar Users:
#    1. User Index: 683, Similarity: JacKH1618, Distance: 0.883
#    2. User Index: 891, Similarity: saumishr, Distance: -0.0009240730445041478
#    3. User Index: 12796, Similarity: vikas340, Distance: -2.001767645904659
# Test User: AldrinRodrigues, Top 3 Similar Users:
#    1. User Index: 604, Similarity: neel771, Distance: 1.0
#    2. User Index: 843, Similarity: amitbhatia.dce89, Distance: 1.0
#    3. User Index: 400, Similarity: rahuljiresal, Distance: 1.0
# Test User: 1987frank, Top 3 Similar Users:
#    1. User Index: 3957, Similarity: mohitb117, Distance: 1.0
#    2. User Index: 3132, Similarity: teja131313, Distance: 1.0
#    3. User Index: 3221, Similarity: pralaybiswas, Distance: 1.0
# Test User: arghyadip.paul, Top 3 Similar Users:
#    1. User Index: 11292, Similarity: confused_desi, Distance: 1.0
#    2. User Index: 10484, Similarity: magpies199, Distance: 1.0
#    3. User Index: 4932, Similarity: Lee2725, Distance: 1.0
# Test User: suraj.chowdhry, Top 3 Similar Users:
#    1. User Index: 14437, Similarity: vaib2033, Distance: 0.9989999999999999
#    2. User Index: 8512, Similarity: smart4u, Distance: 0.9986999999999999
#    3. User Index: 16162, Similarity: love.goyal, Distance: 0.997
# Test User: wise1991, Top 3 Similar Users:
#    1. User Index: 12101, Similarity: hmisra77, Distance: 1.0
#    2. User Index: 4313, Similarity: swatkat93, Distance: 1.0
#    3. User Index: 8745, Similarity: krishchow, Distance: 1.0
# Test User: hellosayan, Top 3 Similar Users:
#    1. User Index: 12617, Similarity: talktorohit54, Distance: 1.0
#    2. User Index: 7337, Similarity: bazinga1990, Distance: 1.0
#    3. User Index: 11290, Similarity: Andystar, Distance: 1.0
# Test User: ommarathe70, Top 3 Similar Users:
#    1. User Index: 19506, Similarity: pearlchryl, Distance: 1.0
#    2. User Index: 7725, Similarity: InterTejas, Distance: 0.9900000000000001
#    3. User Index: 4002, Similarity: kurt cobain, Distance: 0.9900000000000001
# Test User: iyervicky, Top 3 Similar Users:
#    1. User Index: 12428, Similarity: sumedhab212, Distance: 1.0
#    2. User Index: 53, Similarity: poojaroutray, Distance: 1.0
#    3. User Index: 7805, Similarity: ashwinmishra, Distance: 1.0
# Test User: preethiblossom, Top 3 Similar Users:
#    1. User Index: 6891, Similarity: rajmohan92, Distance: 0.999
#    2. User Index: 5832, Similarity: Ginny47889, Distance: 0.9986
#    3. User Index: 8829, Similarity: kurt, Distance: 0.9982
# Test User: pavan1310, Top 3 Similar Users:
#    1. User Index: 10041, Similarity: venzidane89, Distance: 1.0
#    2. User Index: 3032, Similarity: sri007, Distance: 1.0
#    3. User Index: 4587, Similarity: Aishwarya23, Distance: 1.0
# Test User: shantanu.deshpande6, Top 3 Similar Users:
#    1. User Index: 6341, Similarity: brilliant, Distance: 1.0
#    2. User Index: 2508, Similarity: ashokramachandra, Distance: 1.0
#    3. User Index: 128, Similarity: devashish22, Distance: 1.0
# Test User: rohitrmd, Top 3 Similar Users:
#    1. User Index: 9891, Similarity: carthik, Distance: 1.0
#    2. User Index: 3075, Similarity: ronin123, Distance: 0.9989999999999999
#    3. User Index: 3588, Similarity: smithakamat, Distance: 0.9988
# Test User: knmahmed, Top 3 Similar Users:
#    1. User Index: 4515, Similarity: kanchan.karadkar, Distance: 1.0
#    2. User Index: 4469, Similarity: shr14289, Distance: 1.0
#    3. User Index: 2940, Similarity: sooritejaswi, Distance: 1.0
# Test User: samarth274, Top 3 Similar Users:
#    1. User Index: 8171, Similarity: styagi, Distance: 1.0
#    2. User Index: 7505, Similarity: humanethb, Distance: 1.0
#    3. User Index: 5900, Similarity: pri1110, Distance: 0.9992000000000001
# Test User: alluriharikishan, Top 3 Similar Users:
#    1. User Index: 11320, Similarity: thromsie, Distance: 1.0
#    2. User Index: 9422, Similarity: gujja, Distance: 1.0
#    3. User Index: 1901, Similarity: bsvkas, Distance: 1.0
# Test User: v.ravi, Top 3 Similar Users:
#    1. User Index: 10041, Similarity: venzidane89, Distance: 1.0
#    2. User Index: 3032, Similarity: sri007, Distance: 1.0
#    3. User Index: 4587, Similarity: Aishwarya23, Distance: 1.0
# Test User: hsirah, Top 3 Similar Users:
#    1. User Index: 2318, Similarity: spytitan2, Distance: 1.0
#    2. User Index: 1995, Similarity: sudhakar553, Distance: 1.0
#    3. User Index: 1183, Similarity: rashid301, Distance: 1.0
# Test User: aps.akshay, Top 3 Similar Users:
#    1. User Index: 14676, Similarity: rohits1991, Distance: 0.999
#    2. User Index: 15628, Similarity: sivakumar_petit, Distance: 0.999
#    3. User Index: 4218, Similarity: prasadkg, Distance: 0.9989999999999999
# Test User: hpawar, Top 3 Similar Users:
#    1. User Index: 3018, Similarity: neharamdeo, Distance: 1.0
#    2. User Index: 2870, Similarity: cooltito, Distance: 1.0
#    3. User Index: 2544, Similarity: govindaba, Distance: 1.0
# Test User: siddharth_55, Top 3 Similar Users:
#    1. User Index: 14740, Similarity: kashishwadhwa, Distance: 1.0
#    2. User Index: 19164, Similarity: karthikreddy, Distance: 0.9990000000000001
#    3. User Index: 8034, Similarity: Mjmit123, Distance: 0.9990000000000001
# Test User: saurabh85, Top 3 Similar Users:
#    1. User Index: 1876, Similarity: ameyjain, Distance: 1.0
#    2. User Index: 1292, Similarity: Dheepak23, Distance: 1.0
#    3. User Index: 1423, Similarity: srohit24, Distance: 1.0
# Test User: haz_dazzler009, Top 3 Similar Users:
#    1. User Index: 10690, Similarity: athira.c, Distance: 1.0
#    2. User Index: 10449, Similarity: saraj, Distance: 1.0
#    3. User Index: 1639, Similarity: Hurricane123, Distance: 1.0
# Test User: sharvarismarathe, Top 3 Similar Users:
#    1. User Index: 5579, Similarity: blackdaemon, Distance: 1.0
#    2. User Index: 2891, Similarity: qplmx12, Distance: 1.0
#    3. User Index: 614, Similarity: vkas29, Distance: 1.0
# Test User: sandeepnl, Top 3 Similar Users:
#    1. User Index: 3049, Similarity: rdhar, Distance: 1.0
#    2. User Index: 1636, Similarity: rishik.bazaz, Distance: 1.0
#    3. User Index: 2783, Similarity: Ankit2010, Distance: 1.0
# Test User: edulixian2190, Top 3 Similar Users:
#    1. User Index: 10719, Similarity: msee2012, Distance: 1.0
#    2. User Index: 3561, Similarity: kaul_ankita, Distance: 1.0
#    3. User Index: 6863, Similarity: abhinavtekumalla, Distance: 1.0
# Test User: darthvader1, Top 3 Similar Users:
#    1. User Index: 12898, Similarity: suhasshanker135, Distance: 1.0
#    2. User Index: 348, Similarity: Lohith2290, Distance: 0.9999
#    3. User Index: 79, Similarity: bhumitra, Distance: 0.9993
# Test User: sidxavier1, Top 3 Similar Users:
#    1. User Index: 14451, Similarity: rezaul7869, Distance: 1.0
#    2. User Index: 1790, Similarity: djram147, Distance: 1.0
#    3. User Index: 10804, Similarity: overdrive, Distance: 1.0
# Test User: jar035, Top 3 Similar Users:
#    1. User Index: 3558, Similarity: kiranrnandanan, Distance: 0.9996999999999999
#    2. User Index: 2571, Similarity: dkarpur, Distance: 0.9996999999999999
#    3. User Index: 1196, Similarity: aesha shah, Distance: 0.9996999999999999
# Test User: monish57, Top 3 Similar Users:
#    1. User Index: 15720, Similarity: Rachna2802, Distance: -1.0169583535611237
#    2. User Index: 20321, Similarity: dheerajkaja, Distance: -3.001012371887895
#    3. User Index: 13601, Similarity: ssjk, Distance: -5.000021067463013
# Test User: tushki1405, Top 3 Similar Users:
#    1. User Index: 13683, Similarity: n4niranjan, Distance: 0.925
#    2. User Index: 3338, Similarity: vtiwari227, Distance: -0.4143549766589716
#    3. User Index: 689, Similarity: Ankit044, Distance: -1.2360822882890514
# Test User: adityadev, Top 3 Similar Users:
#    1. User Index: 9530, Similarity: iamyogesh, Distance: -0.011246834358456637
#    2. User Index: 17860, Similarity: pulkitsachdeva, Distance: -1.2384389649932381
#    3. User Index: 10659, Similarity: arch0790, Distance: -2.0000166666203705
# Test User: silent.prince90, Top 3 Similar Users:
#    1. User Index: 15432, Similarity: AbhishekMasters, Distance: -0.005665729753181914
#    2. User Index: 697, Similarity: sahilpt, Distance: -1.0000359996760055
#    3. User Index: 20121, Similarity: rokidj, Distance: -1.000820654131699
# Test User: msbmunees, Top 3 Similar Users:
#    1. User Index: 7444, Similarity: RamMuthukrishnan, Distance: -1.0000005624999209
#    2. User Index: 10711, Similarity: siddhu222, Distance: -1.0000015624993899
#    3. User Index: 20599, Similarity: sambitshankar, Distance: -1.0003330347719603
# Test User: Sudeep Krishnadasan, Top 3 Similar Users:
#    1. User Index: 14296, Similarity: kumarrangarajan, Distance: 1.0
#    2. User Index: 10851, Similarity: WIMWI, Distance: 1.0
#    3. User Index: 801, Similarity: dharmendraonline, Distance: 1.0
# Test User: aspirantpraj, Top 3 Similar Users:
#    1. User Index: 7535, Similarity: swapnildinkar, Distance: 0.9993
#    2. User Index: 20059, Similarity: almathews, Distance: 0.9988
#    3. User Index: 301, Similarity: Dark_Knight, Distance: 0.9988
# Test User: acebrains.undefined, Top 3 Similar Users:
#    1. User Index: 10594, Similarity: dude_51189, Distance: 0.9992000000000001
#    2. User Index: 3005, Similarity: annice, Distance: 0.9992000000000001
#    3. User Index: 306, Similarity: pst, Distance: 0.9992000000000001
# Test User: sathish261990, Top 3 Similar Users:
#    1. User Index: 10885, Similarity: shaariq2008, Distance: 1.0
#    2. User Index: 6186, Similarity: mssept10, Distance: 1.0
#    3. User Index: 7752, Similarity: prashanth, Distance: 1.0
# Test User: smishra84, Top 3 Similar Users:
#    1. User Index: 20513, Similarity: smishra84, Distance: -3.1231056256176606
#    2. User Index: 10303, Similarity: kavini12, Distance: -15.031590095807715
#    3. User Index: 13597, Similarity: bharatrao2305@gmail.com, Distance: -20.119388272390847
# Test User: shankhs, Top 3 Similar Users:
#    1. User Index: 7791, Similarity: ykh015, Distance: 1.0
#    2. User Index: 1831, Similarity: agashegaurav, Distance: 1.0
#    3. User Index: 6344, Similarity: bindu96, Distance: 1.0
# Test User: saggitarianamit, Top 3 Similar Users:
#    1. User Index: 12286, Similarity: test01, Distance: 1.0
#    2. User Index: 8467, Similarity: Divya Karthikeyan, Distance: 1.0
#    3. User Index: 7144, Similarity: holdron, Distance: 0.999
# Test User: yuvarajchiyyodu, Top 3 Similar Users:
#    1. User Index: 4991, Similarity: nitzee, Distance: 1.0
#    2. User Index: 2070, Similarity: chinnikrishna, Distance: 1.0
#    3. User Index: 3759, Similarity: Aswin448, Distance: 1.0
# Test User: msharma, Top 3 Similar Users:
#    1. User Index: 5120, Similarity: jainam16, Distance: 0.9998999999999999
#    2. User Index: 9590, Similarity: bhargavraj, Distance: 0.9997
#    3. User Index: 18876, Similarity: jacks1489, Distance: 0.9996999999999999
# Test User: varkhtohr, Top 3 Similar Users:
#    1. User Index: 15359, Similarity: ninmander, Distance: 0.9998
#    2. User Index: 18602, Similarity: rege.twisha, Distance: 0.9997999999999999
#    3. User Index: 4553, Similarity: sanketk, Distance: 0.9997999999999999
# Test User: rnadts, Top 3 Similar Users:
#    1. User Index: 2141, Similarity: rohan514, Distance: -2.162376479801227
#    2. User Index: 8432, Similarity: chahat87, Distance: -3.125
#    3. User Index: 9735, Similarity: riverside, Distance: -3.1258332491752503
# Test User: karthikrama7, Top 3 Similar Users:
#    1. User Index: 150, Similarity: herat, Distance: 1.0
#    2. User Index: 18751, Similarity: sudhakarsweet, Distance: 1.0
#    3. User Index: 11589, Similarity: judgementdey, Distance: 0.9990000000000001
# Test User: apoorvag, Top 3 Similar Users:
#    1. User Index: 4841, Similarity: akashneo, Distance: 1.0
#    2. User Index: 3555, Similarity: siddixit1986, Distance: 1.0
#    3. User Index: 3376, Similarity: munafshaik, Distance: 1.0
# Test User: verukal, Top 3 Similar Users:
#    1. User Index: 568, Similarity: vivek0989, Distance: 1.0
#    2. User Index: 6469, Similarity: azalea, Distance: 1.0
#    3. User Index: 10680, Similarity: uday1489, Distance: 0.9999999999999999
# Test User: write.to.sparsh.raj, Top 3 Similar Users:
#    1. User Index: 2888, Similarity: Swap1802, Distance: 1.0
#    2. User Index: 1999, Similarity: deepakm, Distance: 1.0
#    3. User Index: 2170, Similarity: karthikbh, Distance: 1.0
# Test User: GaneshReddy.A.V.D, Top 3 Similar Users:
#    1. User Index: 3273, Similarity: eduaccount, Distance: 0.999
#    2. User Index: 1954, Similarity: poovath, Distance: 0.998
#    3. User Index: 18306, Similarity: astonmartin, Distance: 0.997
# Test User: ykombinator, Top 3 Similar Users:
#    1. User Index: 7899, Similarity: hrishimania, Distance: -0.0027342619059149698
#    2. User Index: 2527, Similarity: RamMuthukrishnan, Distance: -0.00989157833898191
#    3. User Index: 11625, Similarity: spprashant, Distance: -0.41421356237309515
# Test User: ujraaja, Top 3 Similar Users:
#    1. User Index: 6434, Similarity: intellectual, Distance: -1.0003239737602505
#    2. User Index: 10613, Similarity: raghavnargotra, Distance: -1.0027543533843586
#    3. User Index: 8239, Similarity: IVB, Distance: -1.6463229205824446
# Test User: pranay01, Top 3 Similar Users:
#    1. User Index: 3446, Similarity: imaginative, Distance: 1.0
#    2. User Index: 6729, Similarity: vkm, Distance: 1.0
#    3. User Index: 7000, Similarity: avaniguptacse, Distance: 0.998
# Test User: neeliyer, Top 3 Similar Users:
#    1. User Index: 16533, Similarity: Mihir Kulkarni, Distance: 1.0
#    2. User Index: 59, Similarity: happy.win20, Distance: 0.9990000000000001
#    3. User Index: 14258, Similarity: vinaygjain, Distance: 0.9990000000000001
# Test User: manipalreddy, Top 3 Similar Users:
#    1. User Index: 5051, Similarity: srij, Distance: 1.0
#    2. User Index: 2519, Similarity: lostinthought, Distance: 1.0
#    3. User Index: 2394, Similarity: garima.kohli, Distance: 1.0
# Test User: passion_follower, Top 3 Similar Users:
#    1. User Index: 17064, Similarity: karthik.krish1, Distance: 0.999
#    2. User Index: 16674, Similarity: GradschoolUSA, Distance: 0.997
#    3. User Index: 9523, Similarity: Iniyavan, Distance: 0.996
# Test User: pradipvit, Top 3 Similar Users:
#    1. User Index: 7322, Similarity: badhrinarayanan.k, Distance: 0.971
#    2. User Index: 5815, Similarity: goutamgre, Distance: -0.0031948963187562462
#    3. User Index: 5288, Similarity: Sabrish, Distance: -0.011187420807834192
# Test User: Nick9589, Top 3 Similar Users:
#    1. User Index: 1666, Similarity: herle89, Distance: 0.9998000000000001
#    2. User Index: 6113, Similarity: cmrar5, Distance: 0.9989999999999999
#    3. User Index: 801, Similarity: dharmendraonline, Distance: 0.9970000000000001
# Test User: shiki87, Top 3 Similar Users:
#    1. User Index: 6180, Similarity: rd1, Distance: 1.0
#    2. User Index: 11806, Similarity: rahulkadukar, Distance: 1.0
#    3. User Index: 3278, Similarity: dhruvbird, Distance: 0.99
# Test User: lavender91, Top 3 Similar Users:
#    1. User Index: 18822, Similarity: Twin1, Distance: 0.9920000000000001
#    2. User Index: 10540, Similarity: ykonduri, Distance: 0.992
#    3. User Index: 8023, Similarity: gmgoutam, Distance: 0.9879999999999999
# Test User: Geetha89, Top 3 Similar Users:
#    1. User Index: 965, Similarity: sidroy09, Distance: 1.0
#    2. User Index: 609, Similarity: sakkumar, Distance: 1.0
#    3. User Index: 434, Similarity: nvijayaram, Distance: 1.0
# Test User: NityaP, Top 3 Similar Users:
#    1. User Index: 19883, Similarity: rachitmehrotra, Distance: 0.992
#    2. User Index: 11056, Similarity: maanitraj, Distance: 0.9410000000000001
#    3. User Index: 13136, Similarity: BioMan, Distance: -2.0000881653711446
